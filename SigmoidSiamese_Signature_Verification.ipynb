# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# !wget http://www.iapr-tc11.org/dataset/4NSigComp2010/Dataset_4NSigComp2010.zip

# %%
#maybe play with this later? For submission to ark.
import zipfile
z = zipfile.ZipFile('/content/sigComp2011-trainingSet.zip', 'r')
z.setpassword(b"I hereby accept the SigComp 2010 disclaimer.") #turn string into bytes to resolve TypeError
z.extractall('/content/')
z.close()

# %%
#@title Parameters
#some parameters 

num_eval = 10 #@param {type: "integer"}
num_batch = 16 #@param {type: "integer"}
num_iterations = 128 #@param {type: "integer"}
num_validations = 250 #@param {type: "integer"}
num_pairs = 3000 #@param {type: "integer"}
learning_rate = 0.0001 #@param {type: "number"}
h = 80 #@param {type: "integer"}
w = 100 #@param {type: "integer"}
shape = (h, w, 1)

# %%
#@title imports
import keras
from keras.preprocessing.image import img_to_array, load_img
import os
from matplotlib import pyplot as plt
import sklearn.metrics
import numpy as np
import cv2
from keras import Sequential
from keras.layers import Dense, Dropout, Input, Lambda, Flatten, Convolution2D, MaxPooling2D, ZeroPadding2D
from keras import backend
from keras.layers.advanced_activations import LeakyReLU
from keras.layers import BatchNormalization
from keras.activations import sigmoid
#import cupy as cp
from keras.regularizers import l2
# from keras.engine.topology import Layer
from keras.layers import Layer #or do i have to use the keras.engine.topolgy? will see.
from keras.utils import to_categorical, plot_model
from keras.models import Model
from keras.optimizers import Adam
import time
from keras.utils import Sequence
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
# plt.xkcd()
import tensorflow as tf
config = tf.ConfigProto()
config.gpu_options.allow_growth = True
session = tf.Session(config=config)
# Out:
# Using TensorFlow backend.
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>

# %%
#@title pre_process_data(dir, h, w):
def pre_process_data(dir, h, w):
#returns X_array w/ superimposed centroids & bounding boxes, labels

#load images in grayscale, resize, turn to array

  grayscale_img_array = [(img_to_array(load_img(dir+"/"+x, color_mode = "grayscale", target_size = (h,w)))) for x in os.listdir(dir)]

#try using openCV imread

  # grayscale_img_array = [cv2.imread(img, cv2.IMREAD_GRAYSCALE) for img in os.listdir(dir)]
  # cv2_imshow(grayscale_img_array[1])

  grayscale_img_array=[(cv2.convertScaleAbs(img)) for img in grayscale_img_array] #convert to uint8 format
#Thresholded images are used to find the weighted centroids of each image. 
#Thresholding is unnecessary but it was a learning experience. 

  thresholded_img_array = [cv2.threshold(img, 170,255,cv2.THRESH_BINARY_INV) for img in grayscale_img_array] #threshold binary is set higher that 127 due to image faintness
  thresholded_img_array = [thresh[1] for thresh in thresholded_img_array] #threshold returns (ret, thresh). Only thresh is needed.

  img_moments = [cv2.moments(thresh) for thresh in thresholded_img_array] #"center of mass" of image. This can be used to find the centroid of the image. 

  center_x_pos = [int(m["m10"] / m["m00"]) for m in img_moments]
  center_y_pos = [int(m["m01"] / m["m00"]) for m in img_moments]

# add "crosshair" to center of grayscale images
# is there a way to do this in one line?

  for x in range(len(grayscale_img_array)):
    (grayscale_img_array[x])[:, center_x_pos[x]] = 0
    (grayscale_img_array[x])[center_y_pos[x], :] = 0

#add bounding box to grayscale images
 
  img_contour_array = [cv2.findContours(thresh, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE) for thresh in thresholded_img_array]


  for i in range(len(grayscale_img_array)):
    x,y,w,h= cv2.boundingRect(img_contour_array[i][0])
    grayscale_img_array[i] = cv2.rectangle(grayscale_img_array[i],(x,y),(x+w,y+h),(0,255,0),1)
#get filenames
  labels = [x.split(".")[0] for x in os.listdir(dir)]
  return grayscale_img_array, labels

# %%
#@title save_img_to_dir(img_array,dir,label)
def save_img_to_dir(img_array, dir, label):
  for x in range(len(img_array)):
    cv2.imwrite(dir+"/"+label+str(x)+".png", img_array[x])

# %%
#@title process_and_save()
def process_and_save():
#Filenames:
#genuine: "Gxxx" = real signatures
#refrence: "Rxxx"= signautres used as a reference for the forgers - can be used as trainingset
#simualted: "Sxxx"= skilled forgeries
#disguise: "Dxxx"= real signatures written in such a way to avoid being recognized

#preprocess images

  train_genuine_dir="/content/drive/My Drive/Dataset_4NSigComp2010/TrainingSet/Genuine"
  train_reference_dir ="/content/drive/My Drive/Dataset_4NSigComp2010/TrainingSet/Reference"
  train_simulated_dir = "/content/drive/My Drive/Dataset_4NSigComp2010/TrainingSet/Simulated"
  train_disguise_dir = "/content/drive/My Drive/Dataset_4NSigComp2010/TrainingSet/Disguise"

  test_reference_dir = "/content/drive/My Drive/Dataset_4NSigComp2010/TestSet/Reference"
  test_questioned_dir = "/content/drive/My Drive/Dataset_4NSigComp2010/TestSet/Questioned"

  X_genuine, genuine_labels = pre_process_data(train_genuine_dir, h,w)
  X_reference, reference_labels = pre_process_data(train_reference_dir, h, w)
  X_simulated, simulated_labels = pre_process_data(train_simulated_dir, h, w)
  X_disguise, disguise_labels = pre_process_data(train_disguise_dir, h, w)

  test_X_reference, test_real_labels = pre_process_data(test_reference_dir, h, w)
  test_X_questioned, test_questioned_labels = pre_process_data(test_questioned_dir, h, w)

  training_real = X_genuine + X_reference + X_disguise

  #saveto:

  train_real_savedir = "/content/drive/My Drive/Dataset_4NSigComp2010/ProcessedTrainingSet/Real"
  train_fake_savedir = "/content/drive/My Drive/Dataset_4NSigComp2010/ProcessedTrainingSet/Fake"

  test_reference_savedir = "/content/drive/My Drive/Dataset_4NSigComp2010/ProcessedTestingSet/Real"
  test_questioned_savedir = "/content/drive/My Drive/Dataset_4NSigComp2010/ProcessedTestingSet/Questioned"

  save_img_to_dir(training_real, train_real_savedir, "TrainReal")
  save_img_to_dir(X_simulated, train_fake_savedir, "TrainFake")

  save_img_to_dir(test_X_reference, test_reference_savedir, "TestRef")
  save_img_to_dir(test_X_questioned, test_questioned_savedir, "TestQuestioned")

# %%
#run *ONCE* to process & save images
process_and_save()

# %%
def bias_initializer(shape, dtype = None):
  return np.random.normal(loc = 0.5, scale = 1e-2, size = shape)

# %%
#@title load_data(dir, shape, label):
def load_data(dir, shape, label = "nolabel" ):

  img_array = [cv2.convertScaleAbs(img_to_array(load_img(dir+"/"+x, color_mode = "grayscale", target_size=(shape[0:2])))) for x in os.listdir(dir)]
  img_array = [img.reshape(shape) for img in img_array]
  img_array = np.asarray(img_array)
  if label == "nolabel":
    return img_array
  else:
    label_array = [label for x in range(len(img_array))]



    #use numpy arrays instead.

    # n_img = len(os.listdir(dir))

    # img_array = np.zeros((n_img, 1))

    # for x in os.listdir(dir):
    #   np.append(img_array, cv2.convertScaleAbs(img_to_array(load_img(dir+"/"+x, color_mode = "grayscale" ))))
    
    # label_array = np.zeros((n_img, 1))

    # for x in range(n_img):
    #   np.append(label_array, label)

    return img_array, label_array

# %%
#@title make_training_set(real,fake)
def make_training_set(real_dir, fake_dir, shape, size):
# return pairs & true/false labels

  X_real = load_data(real_dir, shape)/255
  X_fake = load_data(fake_dir, shape)/255
# 1 = genuine pair
# 0 = false pair

# list of size size of 0,1 for genuine/fake pairs
# 0 = real,real -> Y = 1 (true match)
# 1 = real,fake -> Y = 0 (no match)

#return_shape = (n_pairs, pairsize (2), h, w, 1)

  X_train = np.zeros(shape = (size, 2, shape[0], shape[1], 1))
  Y_train = np.zeros(shape = (size, 1))
  seed = np.random.randint(0, 2, size = size)
  for x in range(seed.shape[0]):
    if seed[x] == 0:
      img_1 = X_real[np.random.randint(0,X_real.shape[0])]
      img_2 = X_real[np.random.randint(0,X_real.shape[0])]
      X_train[x, 0, :, :, 0] = img_1.reshape(shape[0], shape[1])
      X_train[x, 1, :, :, 0] = img_2.reshape(shape[0], shape[1])
      Y_train[x] = 1

    if seed[x] == 1:
      img_1 = X_real[np.random.randint(0,X_real.shape[0])]
      img_2 = X_fake[np.random.randint(0,X_fake.shape[0])]
      X_train[x, 0, :, :, 0] = img_1.reshape(shape[0], shape[1])
      X_train[x, 1, :, :, 0] = img_2.reshape(shape[0], shape[1])
      Y_train[x] = 0

  # Y_train = to_categorical(Y_train) #techically not necessary because everything is 0/1 already, but I wanted to do it.

  return X_train, Y_train

# %%
#@title create_network(shape):

def create_network(shape):
  net = Sequential()
  #conv/fc layer -> batchnorm -> activation -> dropout
  #using tensorflow backend, so dataformat = 'channels_last'
  
  net.add(Convolution2D(32,  kernel_size=(4,4), padding = 'valid', data_format = "channels_last", bias_initializer= bias_initializer,
                        input_shape = shape, kernel_initializer= "glorot_normal", kernel_regularizer = l2(2e-4)))
  net.add(BatchNormalization())
  net.add(LeakyReLU(alpha = (0.3)))
  net.add(MaxPooling2D(pool_size=(2,2)))
  net.add(Dropout(0.3))
  
  net.add(Convolution2D(64,  kernel_size=(2,2), padding = 'valid', data_format = "channels_last", bias_initializer= bias_initializer,
                        kernel_initializer= "glorot_normal", kernel_regularizer=l2(2e-4)))
  net.add(BatchNormalization())
  net.add(LeakyReLU(alpha = (0.3)))
  net.add(MaxPooling2D(pool_size = (2,2)))
  net.add(Dropout(0.3))
  
  
  net.add(Flatten())

  net.add(Dense(64, kernel_initializer= "glorot_normal", kernel_regularizer= l2(2e-4),
                bias_initializer= bias_initializer))
  net.add(LeakyReLU(alpha = (0.3)))
  net.add(Dropout(0.3))
  
  net.add(Dense(64, activation = 'sigmoid', bias_initializer= bias_initializer, kernel_regularizer= l2(2e-4)))
  
  return net

# %%
#@title show_img
def show_img(img, title= ""):
  plt.imshow(img, cmap = 'gray')
  plt.title(title)

# %%
#@title make training arrays
train_real_dir = "/content/drive/My Drive/Dataset_4NSigComp2010/rawTrainingSet/Real"
train_fake_dir = "/content/drive/My Drive/Dataset_4NSigComp2010/rawTrainingSet/Fake"

X_train, Y_train = make_training_set(train_real_dir, train_fake_dir, shape, num_pairs)

# %% [markdown]
# #@title model diagram
#
#
# add a @ to [model diagram] later to show
# [model diagram](https://drive.google.com/uc?id=16-4s61R1rnkn3l8gS3ESLCO_2QMERIhm)

# %%
#@title testing arrays
test_ref_dir = "/content/drive/My Drive/Dataset_4NSigComp2010/TestSet/Reference"
test_questioned_dir = "/content/drive/My Drive/Dataset_4NSigComp2010/TestSet/Questioned"

test_ref = load_data(test_ref_dir, shape)
test_questioned = load_data(test_questioned_dir, shape)

# %%
steven_model.save_weights('/content/drive/My Drive/Dataset_4NSigComp2010/steven/steven.h5')

# %%
steven_model.load_weights('/content/drive/My Drive/Dataset_4NSigComp2010/steven/steven.h5')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-fbfd9a17ada6> in <module>()
# ----> 1 steven_model.load_weights('/content/drive/My Drive/Dataset_4NSigComp2010/steven/steven.h5')
#
# NameError: name 'steven_model' is not defined

# %%
x_train, x_test, y_train, y_test = train_test_split(X_train, Y_train, test_size=.25)
img_1_array = x_train[:,0]
img_2_array = x_train[:,1]

# %%
pred = steven_model.predict([x_test[:,0], x_test[:,1]])

# %%
a = pred.ravel().tolist()
b = y_test.ravel().tolist()
for x in range(100):
  print(int(np.round(a[x], 0)), int(b[x]))

# %%
def display_triplet(tripletbatch):
  nrows = tripletbatch[0].shape[0]

  for x in range(len(tripletbatch[0])):
    fig = plt.figure(figsize=(27, 9*len(tripletbatch)))
    for i in range(3):
      sub = fig.add_subplot(3,9, i+1)
      plt.axis("off")
      plt.imshow(tripletbatch[i][x], cmap = "gray" )
      sub.title.set_text(labels[i])

# %%
def return_labels(pred):
  a = pred.ravel()
  ret = []
  for x in range(len(a)):
    if a[x] < 0.5:
      ret.append("forgery")
    else:
      ret.append("real")
  return ret

# %%
def show_predictions(x_test, y_test, pred, num_show):
  pred_labels = return_labels(pred)
  ref_labels = return_labels(y_test)
  for i in range(num_show):
    print(i)
    i = np.random.randint(0, pred.shape[0])
    fig = plt.figure(figsize = (50,25))
    for y in range(2):
      print(y)
      sub = fig.add_subplot(25,25,i+1)
      plt.axis("off")
      plt.imshow(x_test[y][i], cmap = "gray")
      title = str("LEFT: REFERENCE, RIGHT: QUESTIONED. PREDICTION:" + pred_labels[i] + "REFERENCE:" + ref_labels[i]) 
      sub.title.set_text(title)

# %%
show_predictions(x_test, y_test, pred, 10)

# %%
history = steven_model.fit(x=[X_train[:,0], X_train[:,1]], y = Y_train, validation_split = 0.25, validation_steps = int(np.abs(np.ceil(num_iterations/num_batch))),
                 epochs = num_iterations, verbose = 1, steps_per_epoch= int(np.abs(np.ceil(num_iterations/num_batch))))
# Out:
# Train on 750 samples, validate on 250 samples
# Epoch 1/128
# 8/8 [==============================] - 4s 530ms/step - loss: 0.7017 - acc: 0.6177 - val_loss: 0.6046 - val_acc: 0.8400
# Epoch 2/128
# 8/8 [==============================] - 3s 315ms/step - loss: 0.5412 - acc: 0.8425 - val_loss: 0.4286 - val_acc: 0.9320
# Epoch 3/128
# 8/8 [==============================] - 3s 315ms/step - loss: 0.4002 - acc: 0.9318 - val_loss: 0.3323 - val_acc: 0.9760
# Epoch 4/128
# 8/8 [==============================] - 3s 315ms/step - loss: 0.3175 - acc: 0.9607 - val_loss: 0.2758 - val_acc: 0.9920
# Epoch 5/128
# 8/8 [==============================] - 3s 315ms/step - loss: 0.2706 - acc: 0.9723 - val_loss: 0.2424 - val_acc: 0.9920
# Epoch 6/128
# 8/8 [==============================] - 3s 314ms/step - loss: 0.2357 - acc: 0.9792 - val_loss: 0.2224 - val_acc: 0.9920
# Epoch 7/128
# 8/8 [==============================] - 3s 314ms/step - loss: 0.2114 - acc: 0.9847 - val_loss: 0.2100 - val_acc: 0.9880
# Epoch 8/128
# 8/8 [==============================] - 3s 314ms/step - loss: 0.1908 - acc: 0.9898 - val_loss: 0.2007 - val_acc: 0.9880
# Epoch 9/128
# 8/8 [==============================] - 3s 315ms/step - loss: 0.1770 - acc: 0.9937 - val_loss: 0.1959 - val_acc: 0.9880
# Epoch 10/128
# 8/8 [==============================] - 3s 315ms/step - loss: 0.1666 - acc: 0.9945 - val_loss: 0.1922 - val_acc: 0.9880
# Epoch 11/128
# 8/8 [==============================] - 3s 317ms/step - loss: 0.1558 - acc: 0.9960 - val_loss: 0.1873 - val_acc: 0.9880
# Epoch 12/128
# 8/8 [==============================] - 3s 314ms/step - loss: 0.1474 - acc: 0.9987 - val_loss: 0.1843 - val_acc: 0.9880
# Epoch 13/128
# 8/8 [==============================] - 3s 316ms/step - loss: 0.1415 - acc: 0.9998 - val_loss: 0.1800 - val_acc: 0.9880
# Epoch 14/128
# 8/8 [==============================] - 3s 315ms/step - loss: 0.1362 - acc: 0.9998 - val_loss: 0.1743 - val_acc: 0.9880
# Epoch 15/128
# 8/8 [==============================] - 3s 316ms/step - loss: 0.1309 - acc: 1.0000 - val_loss: 0.1709 - val_acc: 0.9880
# Epoch 16/128
# 8/8 [==============================] - 3s 315ms/step - loss: 0.1269 - acc: 0.9998 - val_loss: 0.1684 - val_acc: 0.9880
# Epoch 17/128
# 8/8 [==============================] - 3s 316ms/step - loss: 0.1238 - acc: 1.0000 - val_loss: 0.1668 - val_acc: 0.9880
# Epoch 18/128
# 8/8 [==============================] - 3s 315ms/step - loss: 0.1208 - acc: 1.0000 - val_loss: 0.1615 - val_acc: 0.9880
# Epoch 19/128
# 8/8 [==============================] - 3s 315ms/step - loss: 0.1167 - acc: 1.0000 - val_loss: 0.1619 - val_acc: 0.9880
# Epoch 20/128
# 8/8 [==============================] - 3s 315ms/step - loss: 0.1139 - acc: 0.9998 - val_loss: 0.1585 - val_acc: 0.9880
# Epoch 21/128
# 8/8 [==============================] - 3s 315ms/step - loss: 0.1128 - acc: 1.0000 - val_loss: 0.1568 - val_acc: 0.9880
# Epoch 22/128
# 8/8 [==============================] - 3s 315ms/step - loss: 0.1103 - acc: 1.0000 - val_loss: 0.1547 - val_acc: 0.9880
# Epoch 23/128
# 8/8 [==============================] - 3s 315ms/step - loss: 0.1083 - acc: 1.0000 - val_loss: 0.1539 - val_acc: 0.9880
# Epoch 24/128
# 8/8 [==============================] - 3s 315ms/step - loss: 0.1063 - acc: 1.0000 - val_loss: 0.1540 - val_acc: 0.9880
# Epoch 25/128
# 8/8 [==============================] - 3s 316ms/step - loss: 0.1041 - acc: 1.0000 - val_loss: 0.1518 - val_acc: 0.9880
# Epoch 26/128
# 8/8 [==============================] - 3s 316ms/step - loss: 0.1027 - acc: 1.0000 - val_loss: 0.1478 - val_acc: 0.9920
# Epoch 27/128
# 8/8 [==============================] - 3s 315ms/step - loss: 0.1008 - acc: 1.0000 - val_loss: 0.1467 - val_acc: 0.9920
# Epoch 28/128
# 8/8 [==============================] - 3s 314ms/step - loss: 0.0990 - acc: 1.0000 - val_loss: 0.1465 - val_acc: 0.9880
# Epoch 29/128
# 8/8 [==============================] - 3s 314ms/step - loss: 0.0990 - acc: 1.0000 - val_loss: 0.1442 - val_acc: 0.9920
# Epoch 30/128
# 8/8 [==============================] - 3s 314ms/step - loss: 0.0971 - acc: 1.0000 - val_loss: 0.1448 - val_acc: 0.9920
# Epoch 31/128
# 8/8 [==============================] - 3s 314ms/step - loss: 0.0952 - acc: 1.0000 - val_loss: 0.1428 - val_acc: 0.9920
# Epoch 32/128
# 8/8 [==============================] - 3s 315ms/step - loss: 0.0938 - acc: 1.0000 - val_loss: 0.1420 - val_acc: 0.9920
# Epoch 33/128
# 8/8 [==============================] - 3s 314ms/step - loss: 0.0928 - acc: 1.0000 - val_loss: 0.1406 - val_acc: 0.9920
# Epoch 34/128
# 8/8 [==============================] - 3s 315ms/step - loss: 0.0916 - acc: 1.0000 - val_loss: 0.1366 - val_acc: 0.9920
# Epoch 35/128
# 8/8 [==============================] - 3s 314ms/step - loss: 0.0911 - acc: 1.0000 - val_loss: 0.1374 - val_acc: 0.9920
# Epoch 36/128
# 8/8 [==============================] - 3s 316ms/step - loss: 0.0901 - acc: 1.0000 - val_loss: 0.1387 - val_acc: 0.9920
# Epoch 37/128
# 8/8 [==============================] - 3s 315ms/step - loss: 0.0882 - acc: 1.0000 - val_loss: 0.1334 - val_acc: 0.9920
# Epoch 38/128
# 8/8 [==============================] - 3s 315ms/step - loss: 0.0879 - acc: 1.0000 - val_loss: 0.1335 - val_acc: 0.9920
# Epoch 39/128
# 8/8 [==============================] - 3s 314ms/step - loss: 0.0867 - acc: 1.0000 - val_loss: 0.1318 - val_acc: 0.9920
# Epoch 40/128
# 8/8 [==============================] - 3s 314ms/step - loss: 0.0856 - acc: 1.0000 - val_loss: 0.1280 - val_acc: 0.9920
# Epoch 41/128
# 8/8 [==============================] - 3s 315ms/step - loss: 0.0849 - acc: 1.0000 - val_loss: 0.1310 - val_acc: 0.9920
# Epoch 42/128
# 8/8 [==============================] - 3s 315ms/step - loss: 0.0844 - acc: 1.0000 - val_loss: 0.1290 - val_acc: 0.9920
# Epoch 43/128
# 8/8 [==============================] - 3s 315ms/step - loss: 0.0832 - acc: 1.0000 - val_loss: 0.1272 - val_acc: 0.9920
# Epoch 44/128
# 8/8 [==============================] - 3s 315ms/step - loss: 0.0824 - acc: 1.0000 - val_loss: 0.1305 - val_acc: 0.9920
# Epoch 45/128
# 8/8 [==============================] - 3s 315ms/step - loss: 0.0818 - acc: 1.0000 - val_loss: 0.1290 - val_acc: 0.9920
# Epoch 46/128
# 8/8 [==============================] - 3s 314ms/step - loss: 0.0812 - acc: 1.0000 - val_loss: 0.1251 - val_acc: 0.9920
# Epoch 47/128
# 8/8 [==============================] - 3s 314ms/step - loss: 0.0806 - acc: 1.0000 - val_loss: 0.1265 - val_acc: 0.9920
# Epoch 48/128
# 8/8 [==============================] - 3s 315ms/step - loss: 0.0796 - acc: 1.0000 - val_loss: 0.1269 - val_acc: 0.9920
# Epoch 49/128
# 8/8 [==============================] - 3s 314ms/step - loss: 0.0785 - acc: 1.0000 - val_loss: 0.1249 - val_acc: 0.9920
# Epoch 50/128
# 8/8 [==============================] - 3s 314ms/step - loss: 0.0785 - acc: 1.0000 - val_loss: 0.1216 - val_acc: 0.9920
# Epoch 51/128
# 8/8 [==============================] - 3s 315ms/step - loss: 0.0776 - acc: 1.0000 - val_loss: 0.1244 - val_acc: 0.9920
# Epoch 52/128
# 8/8 [==============================] - 3s 315ms/step - loss: 0.0768 - acc: 1.0000 - val_loss: 0.1231 - val_acc: 0.9920
# Epoch 53/128
# 8/8 [==============================] - 3s 314ms/step - loss: 0.0762 - acc: 1.0000 - val_loss: 0.1208 - val_acc: 0.9920
# Epoch 54/128
# 8/8 [==============================] - 3s 315ms/step - loss: 0.0755 - acc: 1.0000 - val_loss: 0.1180 - val_acc: 0.9920
# Epoch 55/128
# 8/8 [==============================] - 3s 314ms/step - loss: 0.0745 - acc: 1.0000 - val_loss: 0.1186 - val_acc: 0.9920
# Epoch 56/128
# 8/8 [==============================] - 3s 316ms/step - loss: 0.0743 - acc: 1.0000 - val_loss: 0.1166 - val_acc: 0.9920
# Epoch 57/128
# 8/8 [==============================] - 3s 315ms/step - loss: 0.0740 - acc: 1.0000 - val_loss: 0.1178 - val_acc: 0.9920
# Epoch 58/128
# 8/8 [==============================] - 3s 315ms/step - loss: 0.0729 - acc: 1.0000 - val_loss: 0.1157 - val_acc: 0.9920
# Epoch 59/128
# 8/8 [==============================] - 3s 315ms/step - loss: 0.0723 - acc: 1.0000 - val_loss: 0.1125 - val_acc: 0.9920
# Epoch 60/128
# 8/8 [==============================] - 3s 315ms/step - loss: 0.0720 - acc: 1.0000 - val_loss: 0.1120 - val_acc: 0.9920
# Epoch 61/128
# 8/8 [==============================] - 3s 315ms/step - loss: 0.0714 - acc: 1.0000 - val_loss: 0.1122 - val_acc: 0.9920
# Epoch 62/128
# 8/8 [==============================] - 3s 315ms/step - loss: 0.0705 - acc: 1.0000 - val_loss: 0.1098 - val_acc: 0.9920
# Epoch 63/128
# 8/8 [==============================] - 3s 315ms/step - loss: 0.0704 - acc: 1.0000 - val_loss: 0.1101 - val_acc: 0.9920
# Epoch 64/128
# 8/8 [==============================] - 3s 315ms/step - loss: 0.0696 - acc: 1.0000 - val_loss: 0.1071 - val_acc: 0.9920
# Epoch 65/128
# 8/8 [==============================] - 3s 315ms/step - loss: 0.0692 - acc: 1.0000 - val_loss: 0.1050 - val_acc: 0.9920
# Epoch 66/128
# 8/8 [==============================] - 3s 314ms/step - loss: 0.0686 - acc: 1.0000 - val_loss: 0.1034 - val_acc: 0.9920
# Epoch 67/128
# 8/8 [==============================] - 3s 314ms/step - loss: 0.0679 - acc: 1.0000 - val_loss: 0.1034 - val_acc: 0.9920
# Epoch 68/128
# 8/8 [==============================] - 3s 314ms/step - loss: 0.0676 - acc: 1.0000 - val_loss: 0.1030 - val_acc: 0.9920
# Epoch 69/128
# 8/8 [==============================] - 3s 315ms/step - loss: 0.0672 - acc: 1.0000 - val_loss: 0.1020 - val_acc: 0.9920
# Epoch 70/128
# 8/8 [==============================] - 3s 314ms/step - loss: 0.0667 - acc: 1.0000 - val_loss: 0.1000 - val_acc: 0.9960
# Epoch 71/128
# 8/8 [==============================] - 3s 314ms/step - loss: 0.0662 - acc: 1.0000 - val_loss: 0.1015 - val_acc: 0.9920
# Epoch 72/128
# 8/8 [==============================] - 3s 314ms/step - loss: 0.0658 - acc: 1.0000 - val_loss: 0.1003 - val_acc: 0.9920
# Epoch 73/128
# 8/8 [==============================] - 3s 314ms/step - loss: 0.0652 - acc: 1.0000 - val_loss: 0.0990 - val_acc: 0.9920
# Epoch 74/128
# 8/8 [==============================] - 3s 313ms/step - loss: 0.0644 - acc: 1.0000 - val_loss: 0.0974 - val_acc: 0.9960
# Epoch 75/128
# 8/8 [==============================] - 3s 314ms/step - loss: 0.0646 - acc: 1.0000 - val_loss: 0.0956 - val_acc: 0.9960
# Epoch 76/128
# 8/8 [==============================] - 3s 314ms/step - loss: 0.0640 - acc: 1.0000 - val_loss: 0.0946 - val_acc: 0.9960
# Epoch 77/128
# 8/8 [==============================] - 3s 314ms/step - loss: 0.0635 - acc: 1.0000 - val_loss: 0.0944 - val_acc: 0.9960
# Epoch 78/128
# 8/8 [==============================] - 3s 313ms/step - loss: 0.0630 - acc: 1.0000 - val_loss: 0.0939 - val_acc: 0.9960
# Epoch 79/128
# 8/8 [==============================] - 3s 314ms/step - loss: 0.0626 - acc: 1.0000 - val_loss: 0.0925 - val_acc: 0.9960
# Epoch 80/128
# 8/8 [==============================] - 3s 313ms/step - loss: 0.0620 - acc: 1.0000 - val_loss: 0.0923 - val_acc: 0.9960
# Epoch 81/128
# 8/8 [==============================] - 3s 314ms/step - loss: 0.0617 - acc: 1.0000 - val_loss: 0.0905 - val_acc: 0.9960
# Epoch 82/128
# 8/8 [==============================] - 3s 314ms/step - loss: 0.0611 - acc: 1.0000 - val_loss: 0.0900 - val_acc: 0.9960
# Epoch 83/128
# 8/8 [==============================] - 3s 315ms/step - loss: 0.0608 - acc: 1.0000 - val_loss: 0.0892 - val_acc: 1.0000
# Epoch 84/128
# 8/8 [==============================] - 3s 314ms/step - loss: 0.0607 - acc: 1.0000 - val_loss: 0.0885 - val_acc: 0.9960
# Epoch 85/128
# 8/8 [==============================] - 3s 315ms/step - loss: 0.0600 - acc: 1.0000 - val_loss: 0.0873 - val_acc: 0.9960
# Epoch 86/128
# 8/8 [==============================] - 3s 314ms/step - loss: 0.0597 - acc: 1.0000 - val_loss: 0.0869 - val_acc: 0.9960
# Epoch 87/128
# 8/8 [==============================] - 3s 314ms/step - loss: 0.0591 - acc: 1.0000 - val_loss: 0.0855 - val_acc: 1.0000
# Epoch 88/128
# 8/8 [==============================] - 3s 314ms/step - loss: 0.0590 - acc: 1.0000 - val_loss: 0.0852 - val_acc: 1.0000
# Epoch 89/128
# 8/8 [==============================] - 3s 314ms/step - loss: 0.0587 - acc: 1.0000 - val_loss: 0.0841 - val_acc: 1.0000
# Epoch 90/128
# 8/8 [==============================] - 3s 314ms/step - loss: 0.0582 - acc: 1.0000 - val_loss: 0.0836 - val_acc: 1.0000
# Epoch 91/128
# 8/8 [==============================] - 3s 314ms/step - loss: 0.0577 - acc: 1.0000 - val_loss: 0.0832 - val_acc: 1.0000
# Epoch 92/128
# 8/8 [==============================] - 3s 314ms/step - loss: 0.0572 - acc: 1.0000 - val_loss: 0.0821 - val_acc: 1.0000
# Epoch 93/128
# 8/8 [==============================] - 3s 314ms/step - loss: 0.0568 - acc: 1.0000 - val_loss: 0.0815 - val_acc: 1.0000
# Epoch 94/128
# 8/8 [==============================] - 3s 315ms/step - loss: 0.0568 - acc: 1.0000 - val_loss: 0.0813 - val_acc: 1.0000
# Epoch 95/128
# 8/8 [==============================] - 3s 314ms/step - loss: 0.0562 - acc: 1.0000 - val_loss: 0.0807 - val_acc: 1.0000
# Epoch 96/128
# 8/8 [==============================] - 3s 314ms/step - loss: 0.0559 - acc: 1.0000 - val_loss: 0.0803 - val_acc: 1.0000
# Epoch 97/128
# 8/8 [==============================] - 3s 314ms/step - loss: 0.0555 - acc: 1.0000 - val_loss: 0.0806 - val_acc: 1.0000
# Epoch 98/128
# 8/8 [==============================] - 3s 314ms/step - loss: 0.0553 - acc: 1.0000 - val_loss: 0.0806 - val_acc: 1.0000
# Epoch 99/128
# 8/8 [==============================] - 3s 313ms/step - loss: 0.0548 - acc: 1.0000 - val_loss: 0.0800 - val_acc: 1.0000
# Epoch 100/128
# 8/8 [==============================] - 3s 314ms/step - loss: 0.0549 - acc: 1.0000 - val_loss: 0.0788 - val_acc: 1.0000
# Epoch 101/128
# 8/8 [==============================] - 3s 314ms/step - loss: 0.0543 - acc: 1.0000 - val_loss: 0.0784 - val_acc: 1.0000
# Epoch 102/128
# 8/8 [==============================] - 3s 314ms/step - loss: 0.0539 - acc: 1.0000 - val_loss: 0.0779 - val_acc: 1.0000
# Epoch 103/128
# 8/8 [==============================] - 3s 314ms/step - loss: 0.0534 - acc: 1.0000 - val_loss: 0.0776 - val_acc: 1.0000
# Epoch 104/128
# 8/8 [==============================] - 3s 314ms/step - loss: 0.0532 - acc: 1.0000 - val_loss: 0.0771 - val_acc: 1.0000
# Epoch 105/128
# 8/8 [==============================] - 3s 315ms/step - loss: 0.0528 - acc: 1.0000 - val_loss: 0.0766 - val_acc: 1.0000
# Epoch 106/128
# 8/8 [==============================] - 3s 314ms/step - loss: 0.0522 - acc: 1.0000 - val_loss: 0.0760 - val_acc: 1.0000
# Epoch 107/128
# 8/8 [==============================] - 3s 314ms/step - loss: 0.0524 - acc: 1.0000 - val_loss: 0.0756 - val_acc: 1.0000
# Epoch 108/128
# 8/8 [==============================] - 3s 314ms/step - loss: 0.0520 - acc: 1.0000 - val_loss: 0.0750 - val_acc: 1.0000
# Epoch 109/128
# 8/8 [==============================] - 3s 314ms/step - loss: 0.0515 - acc: 1.0000 - val_loss: 0.0751 - val_acc: 1.0000
# Epoch 110/128
# 8/8 [==============================] - 3s 314ms/step - loss: 0.0513 - acc: 1.0000 - val_loss: 0.0744 - val_acc: 1.0000
# Epoch 111/128
# 8/8 [==============================] - 3s 313ms/step - loss: 0.0509 - acc: 1.0000 - val_loss: 0.0739 - val_acc: 1.0000
# Epoch 112/128
# 8/8 [==============================] - 3s 314ms/step - loss: 0.0507 - acc: 1.0000 - val_loss: 0.0736 - val_acc: 1.0000
# Epoch 113/128
# 8/8 [==============================] - 3s 315ms/step - loss: 0.0503 - acc: 1.0000 - val_loss: 0.0732 - val_acc: 1.0000
# Epoch 114/128
# 8/8 [==============================] - 3s 314ms/step - loss: 0.0499 - acc: 1.0000 - val_loss: 0.0725 - val_acc: 1.0000
# Epoch 115/128
# 8/8 [==============================] - 3s 314ms/step - loss: 0.0497 - acc: 1.0000 - val_loss: 0.0724 - val_acc: 1.0000
# Epoch 116/128
# 8/8 [==============================] - 3s 313ms/step - loss: 0.0492 - acc: 1.0000 - val_loss: 0.0718 - val_acc: 1.0000
# Epoch 117/128
# 8/8 [==============================] - 3s 314ms/step - loss: 0.0492 - acc: 1.0000 - val_loss: 0.0717 - val_acc: 1.0000
# Epoch 118/128
# 8/8 [==============================] - 3s 314ms/step - loss: 0.0489 - acc: 1.0000 - val_loss: 0.0710 - val_acc: 1.0000
# Epoch 119/128
# 8/8 [==============================] - 3s 314ms/step - loss: 0.0487 - acc: 1.0000 - val_loss: 0.0709 - val_acc: 1.0000
# Epoch 120/128
# 8/8 [==============================] - 3s 314ms/step - loss: 0.0483 - acc: 1.0000 - val_loss: 0.0704 - val_acc: 1.0000
# Epoch 121/128
# 8/8 [==============================] - 3s 314ms/step - loss: 0.0479 - acc: 1.0000 - val_loss: 0.0699 - val_acc: 1.0000
# Epoch 122/128
# 8/8 [==============================] - 3s 314ms/step - loss: 0.0477 - acc: 1.0000 - val_loss: 0.0695 - val_acc: 1.0000
# Epoch 123/128
# 8/8 [==============================] - 3s 314ms/step - loss: 0.0474 - acc: 1.0000 - val_loss: 0.0692 - val_acc: 1.0000
# Epoch 124/128
# 8/8 [==============================] - 3s 314ms/step - loss: 0.0472 - acc: 1.0000 - val_loss: 0.0685 - val_acc: 1.0000
# Epoch 125/128
# 8/8 [==============================] - 3s 314ms/step - loss: 0.0468 - acc: 1.0000 - val_loss: 0.0683 - val_acc: 1.0000
# Epoch 126/128
# 8/8 [==============================] - 3s 313ms/step - loss: 0.0465 - acc: 1.0000 - val_loss: 0.0681 - val_acc: 1.0000
# Epoch 127/128
# 8/8 [==============================] - 3s 314ms/step - loss: 0.0463 - acc: 1.0000 - val_loss: 0.0676 - val_acc: 1.0000
# Epoch 128/128
# 8/8 [==============================] - 3s 314ms/step - loss: 0.0459 - acc: 1.0000 - val_loss: 0.0673 - val_acc: 1.0000

# %%
plt.plot(history.history['acc'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# Plot training & validation loss values
plt.plot(history.history['loss'])

plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %%
#@title oldtrain!

train_datagen = keras.preprocessing.image.ImageDataGenerator(
  shear_range = 0.2,
  zoom_range = 0.2, 
)

train_generator1 = train_datagen.flow_from_directory(
    directory = "/content/drive/My Drive/Dataset_4NSigComp2010/ProcessedTrainingSet",
    batch_size = num_batch,
    color_mode = "grayscale",
    target_size = shape[0:2],
    shuffle = True,
    class_mode = "binary",
)

train_generator2 = train_datagen.flow_from_directory(
    directory = "/content/drive/My Drive/Dataset_4NSigComp2010/ProcessedTrainingSet",
    batch_size = num_batch,
    color_mode = "grayscale",
    target_size = shape[0:2],
    shuffle = True,
    class_mode = "binary",
)

#dual_train_generator = double_gen(train_generator1, train_generator2)

dual_train_generator = double_generator(train_generator1, train_generator2)

steven_model.fit_generator(dual_train_generator,use_multiprocessing= True, epochs = num_iterations,
                           verbose = 1, steps_per_epoch= int(np.abs(np.ceil(num_iterations/num_batch))))

# %%
def square_distance(xandy):
  x,y=xandy
  return backend.sqrt(backend.sum(backend.square(x - y), axis=1, keepdims=True))

# %%
def square_distance_shape(shape):
  return (shape[0], 1)

# %%
def contrastive_loss(y_true, y_pred):
    '''Contrastive loss from Hadsell-et-al.'06
    http://yann.lecun.com/exdb/publis/pdf/hadsell-chopra-lecun-06.pdf
    '''
    margin = 1
    return backend.mean(y_true * backend.square(y_pred) + (1 - y_true) * backend.square(backend.maximum(margin - y_pred, 0)))

# %%
#main

steven = create_network(shape)
steven.summary()

input_1 = Input(shape=shape)
input_2 = Input(shape=shape)

network_1 = steven(input_1)
network_2 = steven(input_2)

dist_layer = Lambda(lambda tensors:backend.abs(tensors[0]-tensors[1]))
distance = dist_layer([network_1, network_2])

output = Dense(1, activation= "sigmoid", bias_initializer= bias_initializer)(distance)

adam = keras.optimizers.adam(lr = learning_rate)

steven_model = Model(input=[input_1, input_2], output = output)

steven_model.compile(loss = keras.losses.binary_crossentropy , optimizer = adam, metrics = ["accuracy"])
steven_model.summary()
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-e36ea0d70522> in <module>()
#       1
# ----> 2 steven = create_network(shape)
#       3 steven.summary()
#       4
#       5 input_1 = Input(shape=shape)
#
# <ipython-input-6-bc3e7ad27b68> in create_network(shape)
#       5   #using tensorflow backend, so dataformat = 'channels_last'
#       6
# ----> 7   net.add(Convolution2D(32,  kernel_size=(4,4), padding = 'valid', data_format = "channels_last", bias_initializer= bias_initializer,
#       8                         input_shape = shape, kernel_initializer= "glorot_normal", kernel_regularizer = l2(2e-4)))
#       9   net.add(BatchNormalization())
#
# NameError: name 'bias_initializer' is not defined
